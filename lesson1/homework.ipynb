# %%
from salt import salt

# %%
salt('Anton Borzenko')
# Out:
# 'e01dac580974ca38'

# %%
import torch
from torch import utils
from torchvision import datasets, transforms
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
path = './MNIST_data'

train_data = datasets.MNIST(path, train=True, download=True, transform=transforms.ToTensor())

def calc_mean_std(data):
    means = np.empty( len(data) )
    squares = np.empty( len(data) )
    for i, obj in enumerate(data):
        means[i] = obj[0][0].mean()
    mean = means.mean()
    
    for i, obj in enumerate(train_data):
        squares[i] = ((obj[0][0] - mean) ** 2).mean()
    std = np.sqrt(squares.mean())
    
    return mean, std

train_mean, train_std = calc_mean_std(train_data)

train_mean, train_std
# Out:
# (0.13066047863205896, 0.30810785926283424)

# %%
mnist_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize( [ train_mean ] , [ train_std ] ),
           ])

def mnist(batch_size=50, shuffle=True, transform=mnist_transform, path='./MNIST_data'):
    train_data = datasets.MNIST(path, train=True, download=True, transform=transform)
    test_data = datasets.MNIST(path, train=False, download=True, transform=transform)
    train_loader = utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=shuffle)
    test_loader = utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=shuffle)
    return train_loader, test_loader

def plot_mnist(images, shape):
    fig = plt.figure(figsize=shape[::-1], dpi=80)
    for j in range(1, len(images) + 1):
        ax = fig.add_subplot(shape[0], shape[1], j)
        ax.matshow(images[j - 1, 0, :, :], cmap = matplotlib.cm.binary)
        plt.xticks(np.array([]))
        plt.yticks(np.array([]))
    plt.show()

# %%
prepared_data = datasets.MNIST(path, train=True, download=True, transform=mnist_transform)

prepared_data[0][0][0]
# Out:
# tensor([[-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241],
#         [-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241],
#         [-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
#          -0.4241, -0.4241, -0.4241, -0.4241],
#         [-0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241, -0.4241,
# ...

# %%
prepared_data[0][0][0].mean(), prepared_data[0][0][0].std()
# Out:
# (tensor(0.0228), tensor(1.0144))
